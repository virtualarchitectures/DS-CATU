# %% [markdown]
# # CATU Landlord Research Tool
#
# This notebook prepares the Colab environment and runs the tool to download the determination orders.
#
# NOTE: As of 24/11/2025 the Colab version is not working as intended due to challenges with the Selenium configuration. Possible fixes:
# 1. Test a package like Google Colab Selenium: https://github.com/jpjacobpadilla/Google-Colab-Selenium
# 2. Replace Selenium with Microsoft Playwright: https://github.com/microsoft/playwright
#
# In the meantime it is recommended to run the program locally.

# %% [markdown]
# ## Clone the GitHub Repository

# %%
# !git clone https://github.com/virtualarchitectures/DS-CATU.git

# %% [markdown]
# ## Move project folders to root directory

# %% [markdown]
# import shutil
# import os
#
# # Define the source folder and destination
# src_folder = 'DS-CATU'
# # Project root folder
# dest_folder = '.'
#
# for filename in os.listdir(src_folder):
#     src_path = os.path.join(src_folder, filename)
#     dest_path = os.path.join(dest_folder, filename)
#
#     shutil.move(src_path, dest_path)
#
# # Check if the source folder is empty and remove it
# if not os.listdir(src_folder):
#     os.rmdir(src_folder)

# %% [markdown]
# ## Run Setup Script

# %%
# !bash setup_colab.sh

# %% [markdown]
# ## Download Determination Orders

# %%
# !python3 src/download_determination_orders.py
